# %% [markdown]
# Importing pandas Library

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %% [markdown]
# Checking the pandas version

# %%
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# Data Frames

# %%
data = {
    'date' : ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04"],
    'close' : [150.0, 152.0, 153.0, 154.0],
    'volume' : [1000, 1200, 1300, 1250],
}

df = pd.DataFrame(data)
print(df)
# Out:
#          date  close  volume
# 0  2024-01-01  150.0    1000
# 1  2024-01-02  152.0    1200
# 2  2024-01-03  153.0    1300
# 3  2024-01-04  154.0    1250

# %% [markdown]
# Printing series

# %%
print(df['date'])
# Out:
# 0    2024-01-01
# 1    2024-01-02
# 2    2024-01-03
# 3    2024-01-04
# Name: date, dtype: object

# %% [markdown]
# Checking a row

# %%
print(df.loc[2]) #also you can use iloc eg print(df.iloc[2])
# Out:
# date      2024-01-03
# close          153.0
# volume          1300
# Name: 2, dtype: object

# %% [markdown]
# This is an apple stocks Data

# %%
df = pd.read_csv('APPL_1D.csv')

# %%
df
# Out:
#             time        open        high         low       close       volume  \
# 0     1320240600   12.144762   12.155382   11.993595   12.063406  328255052.0
# 1     1320327000   12.113800   12.245232   12.001184   12.235220  441524796.0
# 2     1320413400   12.203650   12.246448   12.116527   12.149313  302228240.0
# 3     1320676200   12.139294   12.142028   12.024551   12.133831  270274636.0
# 4     1320762600   12.209111   12.384869   12.189383   12.331139  400439768.0
# ...          ...         ...         ...         ...         ...          ...
# 2915  1686058200  179.965000  180.120000  177.430000  179.210000   64848374.0
# 2916  1686144600  178.440000  181.210000  177.320000  177.820000   61944615.0
# 2917  1686231000  177.895000  180.840000  177.460000  180.570000   50214881.0
# 2918  1686317400  181.500000  182.230000  180.630000  180.960000   48899973.0
# 2919  1686576600  181.270000         NaN         NaN         NaN          NaN
#
#          Volume MA
# ...

# %%
df.describe()
# Out:
#                time    open    high     low   close        volume    Volume MA
# count       2920.00 2920.00 2919.00 2919.00 2919.00       2919.00      2919.00
# mean  1503502927.40   59.74   60.38   59.07   59.75  200558014.51 202115717.49
# std    105701072.41   51.30   51.90   50.66   51.31  171035615.19 148989947.08
# min   1320240600.00    0.00   11.27   11.03   11.04   35195860.00  50684940.65
# 25%   1412062200.00   21.83   22.09   21.62   21.85   91766241.00 101733696.10
# 50%   1503451800.00   36.49   36.72   36.18   36.58  137148384.00 138776456.20
# 75%   1595057400.00   93.83   94.55   92.27   93.84  247976166.00 250714603.00
# max   1686576600.00  182.63  184.95  180.63  180.96 1506113440.00 807241634.00

# %% [markdown]
# We need to drop the volume column since I think we dont understand what it means
#
# we will use the axis = 1 ince we need to specify that it is a column not a row

# %%
df = df.drop('Volume MA', axis=1)

# %%
df
# Out:
#             time   open   high    low  close       volume
# 0     1320240600  12.14  12.16  11.99  12.06 328255052.00
# 1     1320327000  12.11  12.25  12.00  12.24 441524796.00
# 2     1320413400  12.20  12.25  12.12  12.15 302228240.00
# 3     1320676200  12.14  12.14  12.02  12.13 270274636.00
# 4     1320762600  12.21  12.38  12.19  12.33 400439768.00
# ...          ...    ...    ...    ...    ...          ...
# 2915  1686058200 179.97 180.12 177.43 179.21  64848374.00
# 2916  1686144600 178.44 181.21 177.32 177.82  61944615.00
# 2917  1686231000 177.90 180.84 177.46 180.57  50214881.00
# 2918  1686317400 181.50 182.23 180.63 180.96  48899973.00
# 2919  1686576600 181.27    NaN    NaN    NaN          NaN
#
# [2920 rows x 6 columns]

# %% [markdown]
# There are some missing data and most of them are null

# %%
df['high'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2915    False
# 2916    False
# 2917    False
# 2918    False
# 2919     True
# Name: high, Length: 2920, dtype: bool

# %% [markdown]
# This is how to check the row that has the missing values and we are quite lucky our data has missing on the whole row

# %%
df.loc[df['high'].isnull()]
# Out:
#             time   open  high  low  close  volume
# 2919  1686576600 181.27   NaN  NaN    NaN     NaN

# %%
df = df.drop(2919)

# %%
df.describe()
# Out:
#                time    open    high     low   close        volume
# count       2919.00 2919.00 2919.00 2919.00 2919.00       2919.00
# mean  1503440209.46   59.70   60.38   59.07   59.75  200558014.51
# std    105664827.31   51.26   51.90   50.66   51.31  171035615.19
# min   1320240600.00    0.00   11.27   11.03   11.04   35195860.00
# 25%   1412040600.00   21.83   22.09   21.62   21.85   91766241.00
# 50%   1503408600.00   36.47   36.72   36.18   36.58  137148384.00
# 75%   1594949400.00   93.36   94.55   92.27   93.84  247976166.00
# max   1686317400.00  182.63  184.95  180.63  180.96 1506113440.00

# %% [markdown]
# In this we need to change the time to be much readable by humans
#
# The time column contains very large numbers. After some research, we understand that these are dates in timestamp format. The numbers represent seconds elapsed since 1970.
#
# Fortunately, pandas has a method to convert these numbers to dates:

# %%
df["time"] = pd.to_datetime(df["time"], unit='s')
print(df["time"])
# Out:
# 0      2011-11-02 13:30:00
# 1      2011-11-03 13:30:00
# 2      2011-11-04 13:30:00
# 3      2011-11-07 14:30:00
# 4      2011-11-08 14:30:00
#                ...
# 2914   2023-06-05 13:30:00
# 2915   2023-06-06 13:30:00
# 2916   2023-06-07 13:30:00
# 2917   2023-06-08 13:30:00
# 2918   2023-06-09 13:30:00
# Name: time, Length: 2919, dtype: datetime64[ns]

# %%
df
# Out:
#                     time   open   high    low  close       volume
# 0    2011-11-02 13:30:00  12.14  12.16  11.99  12.06 328255052.00
# 1    2011-11-03 13:30:00  12.11  12.25  12.00  12.24 441524796.00
# 2    2011-11-04 13:30:00  12.20  12.25  12.12  12.15 302228240.00
# 3    2011-11-07 14:30:00  12.14  12.14  12.02  12.13 270274636.00
# 4    2011-11-08 14:30:00  12.21  12.38  12.19  12.33 400439768.00
# ...                  ...    ...    ...    ...    ...          ...
# 2914 2023-06-05 13:30:00 182.63 184.95 178.03 179.58 121946497.00
# 2915 2023-06-06 13:30:00 179.97 180.12 177.43 179.21  64848374.00
# 2916 2023-06-07 13:30:00 178.44 181.21 177.32 177.82  61944615.00
# 2917 2023-06-08 13:30:00 177.90 180.84 177.46 180.57  50214881.00
# 2918 2023-06-09 13:30:00 181.50 182.23 180.63 180.96  48899973.00
#
# [2919 rows x 6 columns]

# %% [markdown]
# If you have a look at the describe you'll see the 0 value in the open column so we need to check the row it is located.

# %%
df.loc[df['open'] == 0]
# Out:
#                    time  open  high   low  close       volume
# 985 2015-10-05 13:30:00  0.00 25.31 24.78  25.17 208258972.00

# %%
df['low_high_avarage'] = (df['low'] + df['high']) / 2
df
# Out:
#                       open   high    low  close       volume  low_high_avarage
# time
# 2011-11-02 13:30:00  12.14  12.16  11.99  12.06 328255052.00             12.07
# 2011-11-03 13:30:00  12.11  12.25  12.00  12.24 441524796.00             12.12
# 2011-11-04 13:30:00  12.20  12.25  12.12  12.15 302228240.00             12.18
# 2011-11-07 14:30:00  12.14  12.14  12.02  12.13 270274636.00             12.08
# 2011-11-08 14:30:00  12.21  12.38  12.19  12.33 400439768.00             12.29
# ...                    ...    ...    ...    ...          ...               ...
# 2023-06-05 13:30:00 182.63 184.95 178.03 179.58 121946497.00            181.49
# 2023-06-06 13:30:00 179.97 180.12 177.43 179.21  64848374.00            178.78
# 2023-06-07 13:30:00 178.44 181.21 177.32 177.82  61944615.00            179.26
# 2023-06-08 13:30:00 177.90 180.84 177.46 180.57  50214881.00            179.15
# 2023-06-09 13:30:00 181.50 182.23 180.63 180.96  48899973.00            181.43
#
# ...

# %%
df.set_index('time', inplace=True)
df
# Out:
#                       open   high    low  close       volume
# time
# 2011-11-02 13:30:00  12.14  12.16  11.99  12.06 328255052.00
# 2011-11-03 13:30:00  12.11  12.25  12.00  12.24 441524796.00
# 2011-11-04 13:30:00  12.20  12.25  12.12  12.15 302228240.00
# 2011-11-07 14:30:00  12.14  12.14  12.02  12.13 270274636.00
# 2011-11-08 14:30:00  12.21  12.38  12.19  12.33 400439768.00
# ...                    ...    ...    ...    ...          ...
# 2023-06-05 13:30:00 182.63 184.95 178.03 179.58 121946497.00
# 2023-06-06 13:30:00 179.97 180.12 177.43 179.21  64848374.00
# 2023-06-07 13:30:00 178.44 181.21 177.32 177.82  61944615.00
# 2023-06-08 13:30:00 177.90 180.84 177.46 180.57  50214881.00
# 2023-06-09 13:30:00 181.50 182.23 180.63 180.96  48899973.00
#
# [2919 rows x 5 columns]

# %% [markdown]
# With that you can use the date to check the data maybe for date, monthly or the whole year look at the below example of me checking the data of the whole year

# %%
df.loc['2023']
# Out:
#                       open   high    low  close       volume
# time
# 2023-01-03 14:30:00 129.90 130.52 123.81 124.71 112117471.00
# 2023-01-04 14:30:00 126.52 128.28 124.72 125.99  89113633.00
# 2023-01-05 14:30:00 126.76 127.40 124.40 124.66  80962708.00
# 2023-01-06 14:30:00 125.64 129.91 124.53 129.24  87754715.00
# 2023-01-09 14:30:00 130.09 133.02 129.51 129.77  70790813.00
# ...                    ...    ...    ...    ...          ...
# 2023-06-05 13:30:00 182.63 184.95 178.03 179.58 121946497.00
# 2023-06-06 13:30:00 179.97 180.12 177.43 179.21  64848374.00
# 2023-06-07 13:30:00 178.44 181.21 177.32 177.82  61944615.00
# 2023-06-08 13:30:00 177.90 180.84 177.46 180.57  50214881.00
# 2023-06-09 13:30:00 181.50 182.23 180.63 180.96  48899973.00
#
# [110 rows x 5 columns]

# %% [markdown]
# you cal also check the daya from 2021 to 2023
# you can do:
#
# df.loc['2021':'2022']

# %%
df.loc[df['open'] == 0]
# Out:
#                      open  high   low  close       volume  low_high_avarage
# time
# 2015-10-05 13:30:00  0.00 25.31 24.78  25.17 208258972.00             25.05

# %%
df.loc[df['open'] == 0, 'open'] = df['low_high_avarage']

# %%
df.loc[df['open'] == 0]
# Out:
# Empty DataFrame
# Columns: [open, high, low, close, volume, low_high_avarage]
# Index: []

# %% [markdown]
# Fetch the date to check the row

# %%
df.loc["2015-10-05"]
# Out:
#                      open  high   low  close       volume  low_high_avarage
# time
# 2015-10-05 13:30:00 25.05 25.31 24.78  25.17 208258972.00             25.05

# %%
df.describe()
# Out:
#          open    high     low   close        volume  low_high_avarage
# count 2919.00 2919.00 2919.00 2919.00       2919.00           2919.00
# mean    59.71   60.38   59.07   59.75  200558014.51             59.73
# std     51.26   51.90   50.66   51.31  171035615.19             51.28
# min     11.18   11.27   11.03   11.04   35195860.00             11.15
# 25%     21.84   22.09   21.62   21.85   91766241.00             21.87
# 50%     36.47   36.72   36.18   36.58  137148384.00             36.55
# 75%     93.36   94.55   92.27   93.84  247976166.00             93.46
# max    182.63  184.95  180.63  180.96 1506113440.00            181.49

# %% [markdown]
# Computing Descriptive Statistics
#
# Pandas offers functions to compute descriptive statistics on your financial data. For instance, you can calculate the mean, median, standard deviation, and other statistics for stock prices of any company:

# %%
mean_prices = df["close"].mean()
median_prices = df["close"].median()
std_prices = df["close"].std()

print("Average closing prices:", round(mean_prices, 2), '$')
print("Median closing prices:", median_prices)
print("Standard deviation of closing prices:", std_prices)
# Out:
# Average closing prices: 59.75 $
# Median closing prices: 36.57614127
# Standard deviation of closing prices: 51.312979089193696

# %% [markdown]
# Calculating a Moving Average
#
# A moving average is a rolling price average. For example, the moving average value for a particular date would be the average of the prices for the previous 50 dates. To calculate rolling values with pandas, use rolling(50) followed by the operation you want to execute. For a 50-day moving average, you'd use rolling() followed by mean():

# %%
df['moving_average'] = df['close'].rolling(2).mean()
df
# Out:
#                       open   high    low  close       volume  \
# time
# 2011-11-02 13:30:00  12.14  12.16  11.99  12.06 328255052.00
# 2011-11-03 13:30:00  12.11  12.25  12.00  12.24 441524796.00
# 2011-11-04 13:30:00  12.20  12.25  12.12  12.15 302228240.00
# 2011-11-07 14:30:00  12.14  12.14  12.02  12.13 270274636.00
# 2011-11-08 14:30:00  12.21  12.38  12.19  12.33 400439768.00
# ...                    ...    ...    ...    ...          ...
# 2023-06-05 13:30:00 182.63 184.95 178.03 179.58 121946497.00
# 2023-06-06 13:30:00 179.97 180.12 177.43 179.21  64848374.00
# 2023-06-07 13:30:00 178.44 181.21 177.32 177.82  61944615.00
# 2023-06-08 13:30:00 177.90 180.84 177.46 180.57  50214881.00
# 2023-06-09 13:30:00 181.50 182.23 180.63 180.96  48899973.00
#
#                      low_high_avarage  moving_average
# time
# 2011-11-02 13:30:00             12.07             NaN
# 2011-11-03 13:30:00             12.12           12.15
# 2011-11-04 13:30:00             12.18           12.19
# ...

# %% [markdown]
# Calculating Returns and Volatility
#
# For instance, you can calculate daily returns and the volatility of your asset. Volatility is a measure of the risk associated with an investment, typically calculated as the standard deviation of returns over a set period.

# %%
df["daily_returns"] = df["close"].pct_change()
df
# Out:
#                       open   high    low  close       volume  \
# time
# 2011-11-02 13:30:00  12.14  12.16  11.99  12.06 328255052.00
# 2011-11-03 13:30:00  12.11  12.25  12.00  12.24 441524796.00
# 2011-11-04 13:30:00  12.20  12.25  12.12  12.15 302228240.00
# 2011-11-07 14:30:00  12.14  12.14  12.02  12.13 270274636.00
# 2011-11-08 14:30:00  12.21  12.38  12.19  12.33 400439768.00
# ...                    ...    ...    ...    ...          ...
# 2023-06-05 13:30:00 182.63 184.95 178.03 179.58 121946497.00
# 2023-06-06 13:30:00 179.97 180.12 177.43 179.21  64848374.00
# 2023-06-07 13:30:00 178.44 181.21 177.32 177.82  61944615.00
# 2023-06-08 13:30:00 177.90 180.84 177.46 180.57  50214881.00
# 2023-06-09 13:30:00 181.50 182.23 180.63 180.96  48899973.00
#
#                      low_high_avarage  moving_average  daily_returns
# time
# 2011-11-02 13:30:00             12.07             NaN            NaN
# 2011-11-03 13:30:00             12.12           12.15           0.01
# ...

# %% [markdown]
# Here's an example of calculating daily returns and 30-day rolling volatility using Pandas:

# %%
df["volatility"] = df["daily_returns"].rolling(30).std()
df
# Out:
#                         open     high      low    close         volume  \
# time
# 2011-11-02 13:30:00  12.1448  12.1554  11.9936  12.0634 328255052.0000
# 2011-11-03 13:30:00  12.1138  12.2452  12.0012  12.2352 441524796.0000
# 2011-11-04 13:30:00  12.2036  12.2464  12.1165  12.1493 302228240.0000
# 2011-11-07 14:30:00  12.1393  12.1420  12.0246  12.1338 270274636.0000
# 2011-11-08 14:30:00  12.2091  12.3849  12.1894  12.3311 400439768.0000
# ...                      ...      ...      ...      ...            ...
# 2023-06-05 13:30:00 182.6300 184.9510 178.0350 179.5800 121946497.0000
# 2023-06-06 13:30:00 179.9650 180.1200 177.4300 179.2100  64848374.0000
# 2023-06-07 13:30:00 178.4400 181.2100 177.3200 177.8200  61944615.0000
# 2023-06-08 13:30:00 177.8950 180.8400 177.4600 180.5700  50214881.0000
# 2023-06-09 13:30:00 181.5000 182.2300 180.6300 180.9600  48899973.0000
#
#                      low_high_avarage  moving_average  daily_returns  \
# time
# ...

# %%
df.sort_values(by='volatility', ascending=True, inplace=True)
df
# Out:
#                        open    high     low   close         volume  \
# time
# 2017-01-27 14:30:00 28.4932 28.5422 28.3672 28.4489  82251776.0000
# 2017-01-30 14:30:00 28.2109 28.3742 28.1480 28.3742 121510012.0000
# 2017-01-31 14:30:00 28.2623 28.3183 28.1386 28.3089 196803972.0000
# 2017-01-26 14:30:00 28.3836 28.5632 28.3672 28.4466 105350304.0000
# 2017-03-16 13:30:00 32.9699 33.0402 32.8622 32.9629  76927992.0000
# ...                     ...     ...     ...     ...            ...
# 2011-12-08 14:30:00 11.8825 12.0054 11.8455 11.8585 376356580.0000
# 2011-12-09 14:30:00 11.9250 11.9611 11.8697 11.9484 297143408.0000
# 2011-12-12 14:30:00 11.8895 11.9569 11.8218 11.8943 301065820.0000
# 2011-12-13 14:30:00 11.9295 12.0024 11.7505 11.8024 339137092.0000
# 2011-12-14 14:30:00 11.7383 11.7589 11.4645 11.5407 407155068.0000
#
#                      low_high_avarage  moving_average  daily_returns  \
# time
# 2017-01-27 14:30:00           28.4547         28.4477         0.0001
# ...

# %%
df.sort_values(by='daily_returns', ascending=True, inplace=True)
df
# Out:
#                         open     high      low    close          volume  \
# time
# 2020-03-16 13:30:00  59.2264  63.4196  58.7491  59.2901  322423460.0000
# 2013-01-24 14:30:00  14.0873  14.2628  13.7887  13.7964 1460853300.0000
# 2019-01-03 14:30:00  34.6406  35.0593  34.1642  34.2100  365248780.0000
# 2020-03-12 13:30:00  62.6510  66.0927  60.7074  60.7637  418474068.0000
# 2020-09-03 13:30:00 124.8251 126.7234 118.5204 118.8942  257599640.0000
# ...                      ...      ...      ...      ...             ...
# 2020-03-02 14:30:00  69.0987  73.7888  67.9825  73.1450  341397356.0000
# 2020-03-24 13:30:00  57.8580  60.6315  57.3538  60.4332  287531092.0000
# 2020-07-31 13:30:00 101.0114 104.4784  98.9902 104.3263  374295468.0000
# 2020-03-13 13:30:00  64.8418  68.5210  61.9191  68.0437  370732128.0000
# 2011-11-02 13:30:00  12.1448  12.1554  11.9936  12.0634  328255052.0000
#
#                      low_high_avarage  moving_average  daily_returns  \
# time
# ...

# %%
df.sort_values(by='daily_returns', ascending=True, inplace=True)
df['change'] = (df['close'] - df['open']) / df['close']
df.sort_values(by='change', ascending=True, inplace=True)
df
# Out:
#                         open     high      low    close          volume  \
# time
# 2020-03-20 13:30:00  60.5066  61.6449  55.8116  56.1152  401693384.0000
# 2015-08-25 13:30:00  25.2479  25.2479  23.5186  23.5732  414406396.0000
# 2020-09-10 13:30:00 118.3827 118.5204 110.6518 111.6256  182274391.0000
# 2012-12-05 14:30:00  17.4227  17.4331  16.4996  16.5003 1044638484.0000
# 2012-04-16 13:30:00  18.5184  18.5251  17.5528  17.6099 1050785048.0000
# ...                      ...      ...      ...      ...             ...
# 2022-10-13 13:30:00 134.3751 142.9360 133.7579 142.3387  113223975.0000
# 2018-12-26 14:30:00  35.6800  37.8285  35.2998  37.8140  234330176.0000
# 2020-02-28 14:30:00  62.9741  68.1514  62.7562  66.9152  426884920.0000
# 2022-02-24 14:30:00 151.4518 161.6459 150.8761 161.5367  141147540.0000
# 2015-08-24 13:30:00  21.5576  24.7230  20.9055  23.4323  648825168.0000
#
#                      low_high_avarage  moving_average  daily_returns  \
# time
# ...
